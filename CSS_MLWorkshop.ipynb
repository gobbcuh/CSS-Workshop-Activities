# %% [markdown]
# <a href="https://colab.research.google.com/github/gobbcuh/CSS-Workshop-Activities/blob/main/CSS_MLWorkshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import sklearn
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# put your answer here
df = pd.read_excel('personality.xlsx')
df.head()
# Out:
#         Name  Post/Share Frequently?  ...  Number of friends/followers  Personality
# 0      Diosa                       0  ...                          212            0
# 1     Stella                       1  ...                         1305            1
# 2  Staphanie                       1  ...                         1080            1
# 3    Wilfred                       1  ...                         1268            1
# 4     Eloisa                       0  ...                          309            0
#
# [5 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Post/Share Frequently?'].plot(kind='hist', bins=20, title='Post/Share Frequently?')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
# put your answer here
df.drop(columns = 'Name', inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Post/Share Frequently?       50 non-null     int64
#  1   Active in social media?      50 non-null     int64
#  2   Replies to comments?         50 non-null     int64
#  3   Number of friends/followers  50 non-null     int64
#  4   Personality                  50 non-null     int64
# dtypes: int64(5)
# memory usage: 2.1 KB

# %%
# put your answer here
df['Personality'].value_counts()
# Out:
# Personality
# 1    32
# 0    18
# Name: count, dtype: int64

# %%
# put your answer here
X = df.drop(columns = 'Personality').values

# %%
# put your answer here
y = df['Personality'].values

# %%
# put your answer here
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)

# %%
# put your answer here
knn = KNeighborsClassifier(n_neighbors = 15)

# %%
# put your answer here
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
# put your answer here
y_pred = knn.predict(X_test)

# %%
# put your answer here
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.6

# %%
knn.predict([[0,1,0,1000]])
# Out:
# array([1])
